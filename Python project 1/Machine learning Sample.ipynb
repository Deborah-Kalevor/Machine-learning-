# %%
# Importing the libraries for the data analysis
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

# %%
# Importing the data sets 
import chardet
# to solve the encoding error from the dataset, we used the chardet library.
with open('C:/Users/DEBORAH KALEVOR/Desktop/Deborah Kalevor(20941295)Python/Honda Dataset.csv', 'rb') as f:
    result = chardet.detect(f.read())
df = pd.read_csv('C:/Users/DEBORAH KALEVOR/Desktop/Deborah Kalevor(20941295)Python/Honda Dataset.csv', 
                 encoding=result['encoding'])
print(df)
# Out:
#       Year   Make                      Model Condition     Price  \
# 0     2023  Honda              Ridgeline RTL       New  $46,370
# 1     2023  Honda          CR-V Hybrid Sport       New  $34,150
# 2     2023  Honda          CR-V Hybrid Sport       New  $34,245
# 3     2022  Honda           Pilot TrailSport       New  $46,500
# 4     2023  Honda  CR-V Hybrid Sport Touring       New  $40,395
# ...    ...    ...                        ...       ...       ...
# 4994  2018  Honda               Accord Sport      Used  $19,999
# 4995  2020  Honda                     Fit LX      Used  $17,495
# 4996  2018  Honda                Civic Sport      Used  $19,500
# 4997  2011  Honda                Accord EX-L      Used  $17,998
# 4998  2023  Honda                Pilot Elite       New  $53,325
#
#       Consumer_Rating  Consumer_Review_#           Exterior_Color  \
# 0                 4.8                  9     Platinum White Pearl
# ...

# %%
# understanding the data
df.describe().T
# Out:
#                           count         mean          std     min     25%  \
# Year                     4999.0  2020.507702     3.711361  1981.0  2019.0
# Consumer_Rating          4999.0     4.569654     0.542453     1.2     4.4
# Consumer_Review_#        4999.0  1288.366673  1969.998095     0.0   126.0
# Comfort_Rating           4447.0     4.817540     0.259030     3.8     4.7
# Interior_Design_Rating   4447.0     4.706814     0.476941     3.0     4.7
# Performance_Rating       4447.0     4.663931     0.351680     3.6     4.5
# Value_For_Money_Rating   4447.0     4.580976     0.372107     3.6     4.2
# Exterior_Styling_Rating  4447.0     4.731954     0.313093     3.9     4.6
# Reliability_Rating       4447.0     4.866269     0.190886     4.0     4.8
#
#                             50%     75%      max
# Year                     2022.0  2023.0   2023.0
# Consumer_Rating             4.7     4.9      5.0
# Consumer_Review_#         697.0  1695.5  29258.0
# ...

# %%
df.head(15)
# Out:
#     Year   Make                      Model Condition     Price  \
# 0   2023  Honda              Ridgeline RTL       New  $46,370
# 1   2023  Honda          CR-V Hybrid Sport       New  $34,150
# 2   2023  Honda          CR-V Hybrid Sport       New  $34,245
# 3   2022  Honda           Pilot TrailSport       New  $46,500
# 4   2023  Honda  CR-V Hybrid Sport Touring       New  $40,395
# 5   2023  Honda               Odyssey EX-L       New  $42,250
# 6   2023  Honda          CR-V Hybrid Sport       New  $34,090
# 7   2023  Honda  CR-V Hybrid Sport Touring       New  $39,845
# 8   2023  Honda  CR-V Hybrid Sport Touring       New  $40,240
# 9   2023  Honda          CR-V Hybrid Sport       New  $34,700
# 10  2023  Honda  CR-V Hybrid Sport Touring       New  $40,850
# 11  2023  Honda                Pilot Elite       New  $53,375
# 12  2022  Honda      Pilot Special Edition       New  $44,600
# 13  2023  Honda                  CR-V EX-L       New  $34,640
# ...

# %%
df.tail(10)
# Out:
#       Year   Make           Model        Condition     Price  Consumer_Rating  \
# 4989  2022  Honda      Pilot EX-L              New  $44,000               4.9
# 4990  2019  Honda  Passport Sport  Honda Certified  $29,995               5.0
# 4991  2009  Honda    Odyssey EX-L             Used   $6,995               4.5
# 4992  2019  Honda    Odyssey EX-L             Used  $24,177               5.0
# 4993  2019  Honda   Passport EX-L             Used  $28,955               3.0
# 4994  2018  Honda    Accord Sport             Used  $19,999               5.0
# 4995  2020  Honda          Fit LX             Used  $17,495               4.3
# 4996  2018  Honda     Civic Sport             Used  $19,500               4.3
# 4997  2011  Honda     Accord EX-L             Used  $17,998               4.6
# 4998  2023  Honda     Pilot Elite              New  $53,325               4.3
#
#       Consumer_Review_#         Exterior_Color Interior_Color  \
# ...

# %%
print(df.dtypes)
# Out:
# Year                         int64
# Make                        object
# Model                       object
# Condition                   object
# Price                       object
# Consumer_Rating            float64
# Consumer_Review_#            int64
# Exterior_Color              object
# Interior_Color              object
# Drivetrain                  object
# MPG                         object
# Fuel_Type                   object
# Transmission                object
# Engine                      object
# VIN                         object
# Stock_#                     object
# Mileage                     object
# Comfort_Rating             float64
# Interior_Design_Rating     float64
# Performance_Rating         float64
# Value_For_Money_Rating     float64
# Exterior_Styling_Rating    float64
# Reliability_Rating         float64
# State                       object
# Seller_Type                 object
# dtype: object

# %%
# checking for missing values 
df.isna().any()
# Out:
# Year                       False
# Make                       False
# Model                      False
# Condition                  False
# Price                      False
# Consumer_Rating            False
# Consumer_Review_#          False
# Exterior_Color              True
# Interior_Color              True
# Drivetrain                  True
# MPG                         True
# Fuel_Type                   True
# Transmission                True
# Engine                      True
# VIN                         True
# Stock_#                     True
# Mileage                     True
# Comfort_Rating              True
# Interior_Design_Rating      True
# Performance_Rating          True
# Value_For_Money_Rating      True
# Exterior_Styling_Rating     True
# Reliability_Rating          True
# State                       True
# Seller_Type                 True
# dtype: bool

# %%
df.isna().any().sum()
# 18 missing columns
# Out:
# 18

# %%
df.isna().sum()
# Out:
# Year                          0
# Make                          0
# Model                         0
# Condition                     0
# Price                         0
# Consumer_Rating               0
# Consumer_Review_#             0
# Exterior_Color               11
# Interior_Color               11
# Drivetrain                   11
# MPG                        1485
# Fuel_Type                    11
# Transmission                 11
# Engine                       11
# VIN                          11
# Stock_#                      11
# Mileage                      11
# Comfort_Rating              552
# Interior_Design_Rating      552
# Performance_Rating          552
# Value_For_Money_Rating      552
# Exterior_Styling_Rating     552
# Reliability_Rating          552
# State                        73
# Seller_Type                  73
# dtype: int64

# %%
# dropping columns with less missing values 
df.dropna(subset=["Exterior_Color", "Interior_Color", "Fuel_Type", "Transmission", "Engine"], inplace=True)

# %%
df.isna().sum()
# Out:
# Year                          0
# Make                          0
# Model                         0
# Condition                     0
# Price                         0
# Consumer_Rating               0
# Consumer_Review_#             0
# Exterior_Color                0
# Interior_Color                0
# Drivetrain                    0
# MPG                        1474
# Fuel_Type                     0
# Transmission                  0
# Engine                        0
# VIN                           0
# Stock_#                       0
# Mileage                       0
# Comfort_Rating              541
# Interior_Design_Rating      541
# Performance_Rating          541
# Value_For_Money_Rating      541
# Exterior_Styling_Rating     541
# Reliability_Rating          541
# State                        62
# Seller_Type                  62
# dtype: int64

# %%
# Checking the values present in the columns
df.Exterior_Color.unique()
# Out:
# array(['Platinum White Pearl', 'Meteorite Gray Metallic',
#        'Sonic Gray Pearl', 'Crystal Black Pearl',
#        'Pacific Pewter Metallic', 'Urban Gray Pearl', 'Still Night Pearl',
#        'Modern Steel Metallic', 'Dark Cherry Pearl',
#        'Lunar Silver Metallic', 'White', 'Sky', 'Obsidian Blue Pearl',
#        'Rallye Red', 'Radiant Red Metallic II', '–', 'Silver', 'Black',
#        'CRYSTAL BLACK', 'Platinum', 'Gray', 'Platinum White',
#        'Silver Metallic', 'Obsidian Black', 'Pewter', 'Midnight Amethyst',
#        'Radiant Red', 'Canyon', 'White Pearl', 'Lunar', 'Crystal',
#        'Aegean Blue Metallic', 'GC', 'Urban Gray', 'Pearl',
#        'Deep Scarlet Pearl', 'Radiant Red Metallic', 'Meteorite', 'Blue',
#        'Gold', 'Sonic Blue', 'Still Night', 'Crystal Black',
#        'Lunar Silver', 'Milano Red', 'Steel Sapphire Metallic',
#        'Obsidian Blue', 'Morning Mist Metallic',
#        'Polished Metal Metallic', 'Purple', 'Red', 'Brown',
# ...

# %%
# Removing non Exterior color types values 
df = df[~df['Exterior_Color'].isin(['UNKNOWN', '1', 'WX / WX'])]
df.Exterior_Color.unique()
# Out:
# array(['Platinum White Pearl', 'Meteorite Gray Metallic',
#        'Sonic Gray Pearl', 'Crystal Black Pearl',
#        'Pacific Pewter Metallic', 'Urban Gray Pearl', 'Still Night Pearl',
#        'Modern Steel Metallic', 'Dark Cherry Pearl',
#        'Lunar Silver Metallic', 'White', 'Sky', 'Obsidian Blue Pearl',
#        'Rallye Red', 'Radiant Red Metallic II', '–', 'Silver', 'Black',
#        'CRYSTAL BLACK', 'Platinum', 'Gray', 'Platinum White',
#        'Silver Metallic', 'Obsidian Black', 'Pewter', 'Midnight Amethyst',
#        'Radiant Red', 'Canyon', 'White Pearl', 'Lunar', 'Crystal',
#        'Aegean Blue Metallic', 'GC', 'Urban Gray', 'Pearl',
#        'Deep Scarlet Pearl', 'Radiant Red Metallic', 'Meteorite', 'Blue',
#        'Gold', 'Sonic Blue', 'Still Night', 'Crystal Black',
#        'Lunar Silver', 'Milano Red', 'Steel Sapphire Metallic',
#        'Obsidian Blue', 'Morning Mist Metallic',
#        'Polished Metal Metallic', 'Purple', 'Red', 'Brown',
# ...

# %%
df.Interior_Color.unique()
# Out:
# array(['Beige', 'Black', 'Mocha', '–', 'Brown', 'Gray', 'Nh-883p/Black',
#        'Blk Lth', 'Blk Lth-Trmmed Seats', 'Ivory', 'Black / Red',
#        'Red / Black', 'NH-797M/BLACK', 'Gry Clth', 'NH-912P/BLACK',
#        'NH-877P/BLACK', 'Blk Perforated Lth-Trmmed', 'Tan', 'Black/Red',
#        'Red', 'YR-642M/BLACK', 'NH-883P/BLACK', 'NH-904M/BLACK',
#        'NH-731P/BLACK', 'Titanium', 'Truffle',
#        'Blk Fabric W/Synthetic Lt', 'Sport', 'Blk Perforated Lth',
#        'Black / Gray', 'Nh-797m/Black', 'B-593M/BLACK', 'Gray / Silver',
#        'Blk Clth', 'Gry Lth', 'Graphite', 'Biege', 'Cream', 'Bge Lth',
#        'Parchment', 'Grey', 'Blue', 'Crystal Black', 'B-640m/Black', '.',
#        'Stone', 'Black / Titanium', 'Gray / Blue', 'Blk Lth-Trmmed',
#        'Select', 'B-637p/Black', 'Gray/Blue', 'NH-830M/BLACK',
#        'Black / Ivory', 'BLACK', 'Interior', 'Burgundy', 'Gray/Black',
#        'Silver', 'B-575p/Black', 'Nh-877p/Black',
# ...

# %%
# Removing non interor color types values 
df = df[~df['Interior_Color'].isin(['Select', '.'])]
df.Interior_Color.unique()
# Out:
# array(['Beige', 'Black', 'Mocha', '–', 'Brown', 'Gray', 'Nh-883p/Black',
#        'Blk Lth', 'Blk Lth-Trmmed Seats', 'Ivory', 'Black / Red',
#        'Red / Black', 'NH-797M/BLACK', 'Gry Clth', 'NH-912P/BLACK',
#        'NH-877P/BLACK', 'Blk Perforated Lth-Trmmed', 'Tan', 'Black/Red',
#        'Red', 'YR-642M/BLACK', 'NH-883P/BLACK', 'NH-904M/BLACK',
#        'NH-731P/BLACK', 'Titanium', 'Truffle',
#        'Blk Fabric W/Synthetic Lt', 'Sport', 'Blk Perforated Lth',
#        'Black / Gray', 'Nh-797m/Black', 'B-593M/BLACK', 'Gray / Silver',
#        'Blk Clth', 'Gry Lth', 'Graphite', 'Biege', 'Cream', 'Bge Lth',
#        'Parchment', 'Grey', 'Blue', 'Crystal Black', 'B-640m/Black',
#        'Stone', 'Black / Titanium', 'Gray / Blue', 'Blk Lth-Trmmed',
#        'B-637p/Black', 'Gray/Blue', 'NH-830M/BLACK', 'Black / Ivory',
#        'BLACK', 'Interior', 'Burgundy', 'Gray/Black', 'Silver',
#        'B-575p/Black', 'Nh-877p/Black', 'Nighthawk Black Pearl / Grey'],
#       dtype=object)

# %%
df.Fuel_Type.unique()
# Out:
# array(['Gasoline', 'Hybrid', '5-Speed A/T', 'A/T', '6-Speed M/T',
#        'CVT Transmission', 'Compressed Natural Gas'], dtype=object)

# %%
# Removing non fuel types values 
non_fuel_values = ['5-Speed A/T', 'A/T', '6-Speed M/T', 'CVT Transmission']
df = df[~df['Fuel_Type'].isin(non_fuel_values)]
df.Fuel_Type.unique()
# Out:
# array(['Gasoline', 'Hybrid', 'Compressed Natural Gas'], dtype=object)

# %%
df.Transmission.unique()
# Out:
# array(['Automatic', 'Automatic CVT', '9-Speed Automatic',
#        '10-Speed Automatic', '10-SPEED A/T', 'continuously variable',
#        'continuously variable (m cvt)', 'continuously variable automatic',
#        'electronic continuously variable', '1-Speed CVT with Overdrive',
#        '9-SPEED A/T', 'Variable', '–', 'OTHER', '6-Speed Manual',
#        '9-Speed Automatic with Overdrive', 'eCVT', 'Manual',
#        'continuously variable w/sport mode',
#        'continuously variable (ll cvt)', '10 speed automatic',
#        '1-Speed Automatic', 'NOT SPECIFIED', 'CVT',
#        'Electronically Controlled Automatic', '6-SPEED M/T',
#        '5-Speed Automatic', '6-Speed Automatic',
#        '10-Speed Automatic with Overdrive', '4-Speed Automatic', '2',
#        'continuously variable (cvt)', '9 speed automatic',
#        '5-Speed Manual', '6-SPEED A/T', '5-SPEED A/T',
#        'TRANSMISSION W DRIVER SELECTABLE MODE',
# ...

# %%
# Removing non Transmission types values 
df = df[~df['Transmission'].isin(['–', 'NOT SPECIFIED', '2'])]
df.Transmission.unique()
# Out:
# array(['Automatic', 'Automatic CVT', '9-Speed Automatic',
#        '10-Speed Automatic', '10-SPEED A/T', 'continuously variable',
#        'continuously variable (m cvt)', 'continuously variable automatic',
#        'electronic continuously variable', '1-Speed CVT with Overdrive',
#        '9-SPEED A/T', 'Variable', 'OTHER', '6-Speed Manual',
#        '9-Speed Automatic with Overdrive', 'eCVT', 'Manual',
#        'continuously variable w/sport mode',
#        'continuously variable (ll cvt)', '10 speed automatic',
#        '1-Speed Automatic', 'CVT', 'Electronically Controlled Automatic',
#        '6-SPEED M/T', '5-Speed Automatic', '6-Speed Automatic',
#        '10-Speed Automatic with Overdrive', '4-Speed Automatic',
#        'continuously variable (cvt)', '9 speed automatic',
#        '5-Speed Manual', '6-SPEED A/T', '5-SPEED A/T',
#        'TRANSMISSION W DRIVER SELECTABLE MODE',
#        'Close-Ratio 6-Speed Manual', '5-SPEED M/T', '4-SPEED A/T',
# ...

# %%
df.Engine.unique()
# Out:
# array(['3.5L V6 24V GDI SOHC', '2.0L I4 16V GDI DOHC Hybrid',
#        '3.5L V6 24V GDI DOHC', '1.5L I4 16V GDI DOHC Turbo',
#        'V6 Cylinder Engine', '4 Cylinder Engine', '1.5L I4 16V DOHC',
#        '2.0L I4 16V GDI DOHC Turbo', '2.0L I4 16V MPFI DOHC Hybrid',
#        'Intercooled Turbo Regular Unleaded I-4 1.5 L/91',
#        '2.0L I4 16V GDI DOHC', '1.8L I4 16V MPFI SOHC',
#        'Gas/Electric I-4 2.0 L/122',
#        'Intercooled Turbo Regular Unleaded I-4 2.0 L/122',
#        'Regular Unleaded V-6 3.5 L/212', '1.5L 4 Cylinder',
#        '2.4L I4 16V GDI DOHC', 'Regular Unleaded I-4 2.0 L/122',
#        'Premium Unleaded V-6 3.5 L/212', '2.4L I4 16V MPFI DOHC',
#        '1.5L I4 16V MPFI DOHC Hybrid', '2.0L I4 16V MPFI DOHC',
#        '2.2L I4 16V MPFI DOHC', '3.5L V6 24V MPFI SOHC', '1.5L 4 Cyl.',
#        'Gas/Electric I-4 1.5 L/91', '3.0L V6 24V MPFI SOHC',
#        '2.2L I4 16V MPFI SOHC', '1.5L I4', '3.5L', '3.5L V6 DOHC 24V',
# ...

# %%
# Filling in missing values with their average
df["Comfort_Rating"].fillna(value=df["Comfort_Rating"].mean(), inplace=True)
df["Performance_Rating"].fillna(value=df["Performance_Rating"].mean(), inplace=True)

# %%
# covert Price to a float 
# Convert object column to float using astype()
# replace 'Not Priced' with NaN
df['Price'] = df['Price'].replace('Not Priced', np.nan)

# drop NaN values since the empty values are few 
df = df.dropna(subset=['Price'])

# convert Price to a float
df['Price'] = df['Price'].replace('[\$,]', '', regex=True).astype(float)

# %%
print(df.dtypes)
# Out:
# Year                         int64
# Make                        object
# Model                       object
# Condition                   object
# Price                      float64
# Consumer_Rating            float64
# Consumer_Review_#            int64
# Exterior_Color              object
# Interior_Color              object
# Drivetrain                  object
# MPG                         object
# Fuel_Type                   object
# Transmission                object
# Engine                      object
# VIN                         object
# Stock_#                     object
# Mileage                     object
# Comfort_Rating             float64
# Interior_Design_Rating     float64
# Performance_Rating         float64
# Value_For_Money_Rating     float64
# Exterior_Styling_Rating    float64
# Reliability_Rating         float64
# State                       object
# Seller_Type                 object
# dtype: object

# %%
df.isna().sum()
# Out:
# Year                          0
# Make                          0
# Model                         0
# Condition                     0
# Price                         0
# Consumer_Rating               0
# Consumer_Review_#             0
# Exterior_Color                0
# Interior_Color                0
# Drivetrain                    0
# MPG                        1412
# Fuel_Type                     0
# Transmission                  0
# Engine                        0
# VIN                           0
# Stock_#                       0
# Mileage                       0
# Comfort_Rating                0
# Interior_Design_Rating      521
# Performance_Rating            0
# Value_For_Money_Rating      521
# Exterior_Styling_Rating     521
# Reliability_Rating          521
# State                        62
# Seller_Type                  62
# dtype: int64

# %%
df.columns
# Out:
# Index(['Year', 'Make', 'Model', 'Condition', 'Price', 'Consumer_Rating',
#        'Consumer_Review_#', 'Exterior_Color', 'Interior_Color', 'Drivetrain',
#        'MPG', 'Fuel_Type', 'Transmission', 'Engine', 'VIN', 'Stock_#',
#        'Mileage', 'Comfort_Rating', 'Interior_Design_Rating',
#        'Performance_Rating', 'Value_For_Money_Rating',
#        'Exterior_Styling_Rating', 'Reliability_Rating', 'State',
#        'Seller_Type'],
#       dtype='object')

# %%
df.Make.unique()
df.Year.unique()
df.Model.unique()
df.Condition.unique()
# Out:
# array(['New', 'Used', 'Honda Certified'], dtype=object)

# %%
# factorizing string colums
# Make
Car = {}
code = 1
for Make in df.Make.unique():
    Car[Make] = code
    code+=1
 
df.replace(Car, inplace=True)
#Years
Years= {}
code = 1
for Year in df.Year.unique():
    Years[Year] = code
    code+=1
    
 
df.replace(Years, inplace=True)
#Models
Models= {}
code = 1
for Model in df.Model.unique():
    Models[Model] = code
    code+=1
    
 
df.replace(Models, inplace=True)

#Conditions
Conditions= {}
code = 1
for Condition in df.Condition.unique():
    Conditions[Condition] = code
    code+=1
    
 
df.replace(Conditions, inplace=True)

# %%
df.head()
# Out:
#    Year  Make  Model  Condition    Price  Consumer_Rating  Consumer_Review_#  \
# 0     1     1      1          1  46370.0              4.8                  9
# 1     1     1      2          1  34150.0              1.7                 24
# 2     1     1      2          1  34245.0              4.7               2869
# 3     2     1      3          1  46500.0              5.0                 12
# 4     1     1      4          1  40395.0              4.4                 12
#
#             Exterior_Color Interior_Color         Drivetrain  ...   Stock_#  \
# 0     Platinum White Pearl          Beige    All-wheel Drive  ...    830164
# 1     Platinum White Pearl          Black                FWD  ...   6402953
# 2  Meteorite Gray Metallic          Black  Front-wheel Drive  ...  PH704805
# 3         Sonic Gray Pearl          Black    All-wheel Drive  ...  5700429B
# 4      Crystal Black Pearl          Black    All-wheel Drive  ...   5705954
#
# ...

# %%
df.Exterior_Color.unique()
df.Interior_Color.unique()
# Out:
# array(['Beige', 'Black', 'Mocha', '–', 'Brown', 'Gray', 'Nh-883p/Black',
#        'Blk Lth', 'Blk Lth-Trmmed Seats', 'Ivory', 'Black / Red',
#        'Red / Black', 'NH-797M/BLACK', 'Gry Clth', 'NH-912P/BLACK',
#        'NH-877P/BLACK', 'Blk Perforated Lth-Trmmed', 'Tan', 'Black/Red',
#        'Red', 'YR-642M/BLACK', 'NH-883P/BLACK', 'NH-904M/BLACK',
#        'NH-731P/BLACK', 'Titanium', 'Truffle',
#        'Blk Fabric W/Synthetic Lt', 'Sport', 'Blk Perforated Lth',
#        'Black / Gray', 'Nh-797m/Black', 'B-593M/BLACK', 'Gray / Silver',
#        'Blk Clth', 'Gry Lth', 'Graphite', 'Biege', 'Cream', 'Bge Lth',
#        'Parchment', 'Grey', 'Blue', 'Crystal Black', 'B-640m/Black',
#        'Stone', 'Black / Titanium', 'Gray / Blue', 'Blk Lth-Trmmed',
#        'B-637p/Black', 'Gray/Blue', 'NH-830M/BLACK', 'Black / Ivory',
#        'BLACK', 'Interior', 'Burgundy', 'Gray/Black', 'Silver',
#        'B-575p/Black', 'Nh-877p/Black', 'Nighthawk Black Pearl / Grey'],
#       dtype=object)

# %%
#Exterior Color
Exterior_Colors= {}
code = 1
for Exterior_Color in df.Exterior_Color.unique():
    Exterior_Colors[Exterior_Color] = code
    code+=1
    
 
df.replace(Exterior_Colors, inplace=True)

# Interior Color
Interior_Colors= {}
code = 1
for Interior_Color in df.Interior_Color.unique():
    Interior_Colors[Interior_Color] = code
    code+=1
# since the Exterior and interior have similar values to avoid the same color factor in both
# we used this formulae
df['Exterior_Color'] = df['Exterior_Color'].replace(Exterior_Colors)
df['Interior_Color'] = df['Interior_Color'].replace(Interior_Colors)

# %%
df.head()
# Out:
#    Year  Make  Model  Condition    Price  Consumer_Rating  Consumer_Review_#  \
# 0     1     1      1          1  46370.0              4.8                  9
# 1     1     1      2          1  34150.0              1.7                 24
# 2     1     1      2          1  34245.0              4.7               2869
# 3     2     1      3          1  46500.0              5.0                 12
# 4     1     1      4          1  40395.0              4.4                 12
#
#    Exterior_Color  Interior_Color         Drivetrain  ...   Stock_# Mileage  \
# 0               1               1    All-wheel Drive  ...    830164      10
# 1               1               2                FWD  ...   6402953      16
# 2               2               2  Front-wheel Drive  ...  PH704805       1
# 3               3               2    All-wheel Drive  ...  5700429B       5
# 4               4               2    All-wheel Drive  ...   5705954       5
#
# ...

# %%
df.Fuel_Type.unique()
df.Transmission.unique()
df.Engine.unique()
# Out:
# array(['3.5L V6 24V GDI SOHC', '2.0L I4 16V GDI DOHC Hybrid',
#        '3.5L V6 24V GDI DOHC', '1.5L I4 16V GDI DOHC Turbo',
#        'V6 Cylinder Engine', '4 Cylinder Engine', '1.5L I4 16V DOHC',
#        '2.0L I4 16V GDI DOHC Turbo', '2.0L I4 16V MPFI DOHC Hybrid',
#        'Intercooled Turbo Regular Unleaded I-4 1.5 L/91',
#        '2.0L I4 16V GDI DOHC', '1.8L I4 16V MPFI SOHC',
#        'Gas/Electric I-4 2.0 L/122',
#        'Intercooled Turbo Regular Unleaded I-4 2.0 L/122',
#        'Regular Unleaded V-6 3.5 L/212', '1.5L 4 Cylinder',
#        '2.4L I4 16V GDI DOHC', 'Regular Unleaded I-4 2.0 L/122',
#        'Premium Unleaded V-6 3.5 L/212', '2.4L I4 16V MPFI DOHC',
#        '1.5L I4 16V MPFI DOHC Hybrid', '2.0L I4 16V MPFI DOHC',
#        '2.2L I4 16V MPFI DOHC', '3.5L V6 24V MPFI SOHC', '1.5L 4 Cyl.',
#        'Gas/Electric I-4 1.5 L/91', '3.0L V6 24V MPFI SOHC',
#        '2.2L I4 16V MPFI SOHC', '1.5L I4', '3.5L', '3.5L V6 DOHC 24V',
# ...

# %%
#Fuel Types
Fuel_Types= {}
code = 1
for Fuel_Type in df.Fuel_Type.unique():
    Fuel_Types[Fuel_Type] = code
    code+=1
    
 
df.replace(Fuel_Types, inplace=True)

#Transmissions
Transmissions= {}
code = 1
for Transmission in df.Transmission.unique():
    Transmissions[Transmission] = code
    code+=1
    
 
df.replace(Transmissions, inplace=True)

#Engines
Engines= {}
code = 1
for Engine in df.Engine.unique():
    Engines[Engine] = code
    code+=1
    
 
df.replace(Engines, inplace=True)

# %%
df.head()
# Out:
#    Year  Make  Model  Condition    Price  Consumer_Rating  Consumer_Review_#  \
# 0     1     1      1          1  46370.0              4.8                  9
# 1     1     1      2          1  34150.0              1.7                 24
# 2     1     1      2          1  34245.0              4.7               2869
# 3     2     1      3          1  46500.0              5.0                 12
# 4     1     1      4          1  40395.0              4.4                 12
#
#    Exterior_Color  Interior_Color         Drivetrain  ...   Stock_#  Mileage  \
# 0               1               1    All-wheel Drive  ...    830164       10
# 1               1               2                FWD  ...   6402953       16
# 2               2               2  Front-wheel Drive  ...  PH704805        1
# 3               3               2    All-wheel Drive  ...  5700429B        5
# 4               4               2    All-wheel Drive  ...   5705954        5
#
# ...

# %%
print(df.dtypes)
# Out:
# Year                         int64
# Make                         int64
# Model                        int64
# Condition                    int64
# Price                      float64
# Consumer_Rating            float64
# Consumer_Review_#            int64
# Exterior_Color               int64
# Interior_Color               int64
# Drivetrain                  object
# MPG                         object
# Fuel_Type                    int64
# Transmission                 int64
# Engine                       int64
# VIN                         object
# Stock_#                     object
# Mileage                     object
# Comfort_Rating             float64
# Interior_Design_Rating     float64
# Performance_Rating         float64
# Value_For_Money_Rating     float64
# Exterior_Styling_Rating    float64
# Reliability_Rating         float64
# State                       object
# Seller_Type                 object
# dtype: object

# %%
#Visualizing data to check graphical relationship between some variables 
import matplotlib.pyplot as plt
df.plot(kind = 'scatter', x = 'Transmission', y = 'Engine')# scatter plot
df.plot(kind = 'hist', x = 'Price', y = 'Model') # histogram
df.plot(kind = 'bar', x = 'Year', y = 'Make')# bar plot
df.plot(kind = 'hist', x = 'Consumer_Rating', y = 'Interior_Color')# histogram plot
plt.show()

# %%
# splitting the data sets into training and testing 
                      
columns = ["Year","Make","Model","Condition","Exterior_Color","Interior_Color","Fuel_Type","Transmission" ,"Engine", 
           "Comfort_Rating","Performance_Rating"]   
x = df[ columns ] 
y = df.Price

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size= 0.2)

# %%
np.random.seed(42)
from sklearn.linear_model import LinearRegression
model1 = LinearRegression()

# %%
model1.fit (x_train,y_train)
# Out:
# LinearRegression()

# %%
predicted = model1.predict( x_test)

# %%
y.head()
# Out:
# 0    46370.0
# 1    34150.0
# 2    34245.0
# 3    46500.0
# 4    40395.0
# Name: Price, dtype: float64

# %%
#Accuracy of the data using the mean squared error
from sklearn.metrics import mean_squared_error
error = mean_squared_error(y_test,predicted)
print(error)
# Out:
# 42345133.36394531

# %%
#root of the mean square
np.sqrt(error)
# Out:
# 6507.313836288005

# %%
#Accuracy of the Linear Regression using the R-square score
from sklearn.metrics import r2_score
# Calculate the R-squared score
r2 = r2_score(y_test,predicted)

# %%
# Print the R-squared score
print('R-squared:', r2)
# Out:
# R-squared: 0.5871294738181358

# %%
np.random.seed(42)
from sklearn.linear_model import LogisticRegression
model2 = LogisticRegression(solver='sag',max_iter=100000) #Using SAG as the solver for Logistic Regression can
#potentially speed up the training time and converge faster to a better solution.

# %%
model2.fit (x_train,y_train)
# Out:
# LogisticRegression(max_iter=100000, solver='sag')

# %%
predicted1 = model2.predict( x_test)

# %%
y.head()
# Out:
# 0    46370.0
# 1    34150.0
# 2    34245.0
# 3    46500.0
# 4    40395.0
# Name: Price, dtype: float64

# %%
#mean square error
error = mean_squared_error(y_test,predicted1)
print(error)
# Out:
# 56208432.49745158

# %%
#mean root square error
np.sqrt(error)
# Out:
# 7497.22832101648

# %%
# Calculate the R-squared score
r3 = r2_score(y_test,predicted1)

# %%
# Print the R-squared score
print('R-squared:', r3)
# Out:
# R-squared: 0.44112048369432955
